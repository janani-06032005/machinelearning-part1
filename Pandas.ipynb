# %% [markdown]
# <a href="https://colab.research.google.com/github/janani-06032005/machinelearning-part1/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# IMPORTING THE PANDAS LIBRARY

# %%
import pandas as pd

# %% [markdown]
# LOADING THE DATASET

# %%
df=pd.read_csv('/content/archive.zip')

# %% [markdown]
# PRINTING THE FIRST 5 ROWS OF DATASET

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2

# %% [markdown]
# PRINTING THE LAST 5 ROWS OF DATASET

# %%
df.tail()
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 501  0.06263  0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273     21.0
# 502  0.04527  0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273     21.0
# 503  0.06076  0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273     21.0
# 504  0.10959  0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273     21.0
# 505  0.04741  0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273     21.0
#
#           B  LSTAT  MEDV
# 501  391.99    NaN  22.4
# 502  396.90   9.08  20.6
# 503  396.90   5.64  23.9
# 504  393.45   6.48  22.0
# 505  396.90   7.88  11.9

# %% [markdown]
# PRINTING THE RANDOM 5 ROWS OF DATAFRAME

# %%
df.sample()
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 488  0.15086  0.0  27.74   0.0  0.609  5.454  92.7  1.8209    4  711     20.1
#
#           B  LSTAT  MEDV
# 488  395.09  18.06  15.2

# %% [markdown]
# RETURNS THE NO:OF ROWS AND COLUMNS

# %%
df.shape
# Out:
# (506, 14)

# %% [markdown]
# GIVES THE COLUMN NAMES

# %%
df.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'MEDV'],
#       dtype='object')

# %% [markdown]
# RETURNS TRUE IF THE MISSING VALUES ARE PRESENT IN PARTICULAR COLUMN

# %%
df.isnull()
# Out:
#       CRIM     ZN  INDUS   CHAS    NOX     RM    AGE    DIS    RAD    TAX  \
# 0    False  False  False  False  False  False  False  False  False  False
# 1    False  False  False  False  False  False  False  False  False  False
# 2    False  False  False  False  False  False  False  False  False  False
# 3    False  False  False  False  False  False  False  False  False  False
# 4    False  False  False  False  False  False  False  False  False  False
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 501  False  False  False  False  False  False  False  False  False  False
# 502  False  False  False  False  False  False  False  False  False  False
# 503  False  False  False  False  False  False  False  False  False  False
# 504  False  False  False  False  False  False  False  False  False  False
# 505  False  False  False  False  False  False   True  False  False  False
#
#      PTRATIO      B  LSTAT   MEDV
# 0      False  False  False  False
# ...

# %% [markdown]
# GIVES THE NUMBER OF MISSING VALUES IN EACH COLUMN

# %%
df.isnull().sum()
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %% [markdown]
# GIVES THE INFORMATION ABOUT THE DATAFRAME

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     486 non-null    float64
#  1   ZN       486 non-null    float64
#  2   INDUS    486 non-null    float64
#  3   CHAS     486 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      486 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    486 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %% [markdown]
# RETURNS TRUE IF THE DUPLICATE VALUE IS PRESENT IN PARTICULAR ROW

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 501    False
# 502    False
# 503    False
# 504    False
# 505    False
# Length: 506, dtype: bool

# %% [markdown]
# GIVES THE NUMBER OF DUPLICATE VALUES

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# GIVES THE NUMBER OF VALUES IN A PARTICULAR COLUMN

# %%
df.value_counts('MEDV')
# Out:
# MEDV
# 50.0    16
# 25.0     8
# 22.0     7
# 23.1     7
# 21.7     7
#         ..
# 25.3     1
# 25.2     1
# 25.1     1
# 6.3      1
# 7.4      1
# Length: 229, dtype: int64

# %% [markdown]
# GROUPS THE VALUE BASED ON SAME MEAN VALUES

# %%
df.groupby('MEDV').mean()
# Out:
#            CRIM         ZN      INDUS   CHAS       NOX      RM         AGE  \
# MEDV
# 5.0   53.136300   0.000000  18.100000  0.000  0.693000  5.5680  100.000000
# 5.6   25.046100   0.000000  18.100000  0.000  0.693000  5.9870  100.000000
# 6.3    9.916550   0.000000  18.100000  0.000  0.693000  5.8520   77.800000
# 7.0   22.964735   0.000000  22.920000  0.000  0.651000  4.9665   99.150000
# 7.2   16.377533   0.000000  18.100000  0.000  0.690667  6.0180   99.366667
# ...         ...        ...        ...    ...       ...     ...         ...
# 46.7   0.298190   0.000000   6.200000  0.000  0.504000  7.6860   17.000000
# 48.3   0.331470   0.000000   6.200000  0.000  0.507000  8.2470         NaN
# 48.5   0.035100  95.000000   2.680000  0.000  0.416100  7.8530   33.200000
# 48.8        NaN  20.000000   3.970000  0.000  0.647000  8.3980   91.500000
# 50.0   2.505641  20.333333  11.860625  0.375  0.566569  7.4840   74.878571
#
# ...

# %% [markdown]
# COUNTS THE TOTAL NO:OF VALUES PRESENT IN EACH COLUMN

# %%
df.count()
# Out:
# CRIM       486
# ZN         486
# INDUS      486
# CHAS       486
# NOX        506
# RM         506
# AGE        486
# DIS        506
# RAD        506
# TAX        506
# PTRATIO    506
# B          506
# LSTAT      486
# MEDV       506
# dtype: int64

# %% [markdown]
# CALCULATES THE MEAN

# %%
df.mean()
# Out:
# CRIM         3.611874
# ZN          11.211934
# INDUS       11.083992
# CHAS         0.069959
# NOX          0.554695
# RM           6.284634
# AGE         68.518519
# DIS          3.795043
# RAD          9.549407
# TAX        408.237154
# PTRATIO     18.455534
# B          356.674032
# LSTAT       12.715432
# MEDV        22.532806
# dtype: float64

# %% [markdown]
# CALCULATES THE STANDARED DEVIATION

# %%
df.std()
# Out:
# CRIM         8.720192
# ZN          23.388876
# INDUS        6.835896
# CHAS         0.255340
# NOX          0.115878
# RM           0.702617
# AGE         27.999513
# DIS          2.105710
# RAD          8.707259
# TAX        168.537116
# PTRATIO      2.164946
# B           91.294864
# LSTAT        7.155871
# MEDV         9.197104
# dtype: float64

# %% [markdown]
# GIVES THE MAXIMUM VALUES IN EACH COLUMN

# %%
df.max()
# Out:
# CRIM        88.9762
# ZN         100.0000
# INDUS       27.7400
# CHAS         1.0000
# NOX          0.8710
# RM           8.7800
# AGE        100.0000
# DIS         12.1265
# RAD         24.0000
# TAX        711.0000
# PTRATIO     22.0000
# B          396.9000
# LSTAT       37.9700
# MEDV        50.0000
# dtype: float64

# %% [markdown]
# GIVES THE MINIMUM  VALUES IN EACH COLUMN

# %%
df.min()
# Out:
# CRIM         0.00632
# ZN           0.00000
# INDUS        0.46000
# CHAS         0.00000
# NOX          0.38500
# RM           3.56100
# AGE          2.90000
# DIS          1.12960
# RAD          1.00000
# TAX        187.00000
# PTRATIO     12.60000
# B            0.32000
# LSTAT        1.73000
# MEDV         5.00000
# dtype: float64

# %% [markdown]
# CALULATES THE TOTAL STATISTICAL METHODS

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  486.000000  486.000000  486.000000  486.000000  506.000000  506.000000
# mean     3.611874   11.211934   11.083992    0.069959    0.554695    6.284634
# std      8.720192   23.388876    6.835896    0.255340    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.081900    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.253715    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.560263   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  486.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.518519    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %% [markdown]
# REMOVES A PARTICULAR ROW

# %%
df.drop(index=0,axis=0)
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 1    0.02731  0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2    0.02729  0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3    0.03237  0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4    0.06905  0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
# 5    0.02985  0.0   2.18   0.0  0.458  6.430  58.7  6.0622    3  222     18.7
# ..       ...  ...    ...   ...    ...    ...   ...     ...  ...  ...      ...
# 501  0.06263  0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273     21.0
# 502  0.04527  0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273     21.0
# 503  0.06076  0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273     21.0
# 504  0.10959  0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273     21.0
# 505  0.04741  0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273     21.0
#
#           B  LSTAT  MEDV
# ...

# %% [markdown]
# REMOVES A PARTICULAR COLUMNS

# %%
df.drop(columns='ZN',axis=1)
# Out:
#         CRIM  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0    0.00632   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1    0.02731   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2    0.02729   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3    0.03237   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4    0.06905   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
# ..       ...    ...   ...    ...    ...   ...     ...  ...  ...      ...
# 501  0.06263  11.93   0.0  0.573  6.593  69.1  2.4786    1  273     21.0
# 502  0.04527  11.93   0.0  0.573  6.120  76.7  2.2875    1  273     21.0
# 503  0.06076  11.93   0.0  0.573  6.976  91.0  2.1675    1  273     21.0
# 504  0.10959  11.93   0.0  0.573  6.794  89.3  2.3889    1  273     21.0
# 505  0.04741  11.93   0.0  0.573  6.030   NaN  2.5050    1  273     21.0
#
#           B  LSTAT  MEDV
# 0    396.90   4.98  24.0
# 1    396.90   9.14  21.6
# ...

# %% [markdown]
# PRINT THE VALUES OF PARTICULAR ROW

# %%
df.iloc[2]
# Out:
# CRIM         0.02729
# ZN           0.00000
# INDUS        7.07000
# CHAS         0.00000
# NOX          0.46900
# RM           7.18500
# AGE         61.10000
# DIS          4.96710
# RAD          2.00000
# TAX        242.00000
# PTRATIO     17.80000
# B          392.83000
# LSTAT        4.03000
# MEDV        34.70000
# Name: 2, dtype: float64

# %% [markdown]
# PRINT THE VALUES OF PARTICULAR COLUMNS

# %%
print(df.iloc[:,0])
# Out:
# 0      0.00632
# 1      0.02731
# 2      0.02729
# 3      0.03237
# 4      0.06905
#         ...
# 501    0.06263
# 502    0.04527
# 503    0.06076
# 504    0.10959
# 505    0.04741
# Name: CRIM, Length: 506, dtype: float64

# %% [markdown]
# RETURNS THE RELATIONSHIP BETWEEN FACTORS

# %%
df.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.191178  0.401863 -0.054355  0.417130 -0.219150  0.354342
# ZN      -0.191178  1.000000 -0.531871 -0.037229 -0.513704  0.320800 -0.563801
# INDUS    0.401863 -0.531871  1.000000  0.059859  0.764866 -0.390234  0.638431
# CHAS    -0.054355 -0.037229  0.059859  1.000000  0.075097  0.104885  0.078831
# NOX      0.417130 -0.513704  0.764866  0.075097  1.000000 -0.302188  0.731548
# RM      -0.219150  0.320800 -0.390234  0.104885 -0.302188  1.000000 -0.247337
# AGE      0.354342 -0.563801  0.638431  0.078831  0.731548 -0.247337  1.000000
# DIS     -0.374166  0.656739 -0.711709 -0.093971 -0.769230  0.205246 -0.744844
# RAD      0.624765 -0.310919  0.604533  0.001468  0.611441 -0.209847  0.458349
# TAX      0.580595 -0.312371  0.731055 -0.032304  0.668023 -0.292048  0.509114
# PTRATIO  0.281110 -0.414046  0.390954 -0.111304  0.188933 -0.355501  0.269226
# ...
